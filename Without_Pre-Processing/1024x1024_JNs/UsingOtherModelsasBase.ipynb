# %%
import os
import shutil
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.models import Model
import matplotlib.pyplot as plt

# Define paths
dataset_folder = 'C:\\Users\\Alexandra\\Documents\\SPRING_2024\\BMEN_689\\Project_2\\Jupyter_Notebook\\1024x1024_Phage_EMs\\'

# Function to split dataset into train/validation/test
def split_dataset(data_folder, train_size=0.6, val_size=0.2, test_size=0.2):
    for class_folder in os.listdir(data_folder):
        class_path = os.path.join(data_folder, class_folder)
        if os.path.isdir(class_path):
            files = os.listdir(class_path)
            train_files, test_files = train_test_split(files, test_size=val_size+test_size, random_state=42)
            val_files, test_files = train_test_split(test_files, test_size=test_size/(val_size+test_size), random_state=42)

            train_folder = os.path.join(data_folder, 'train', class_folder)
            val_folder = os.path.join(data_folder, 'validation', class_folder)
            test_folder = os.path.join(data_folder, 'test', class_folder)
            for folder in [train_folder, val_folder, test_folder]:
                if not os.path.exists(folder):
                    os.makedirs(folder)

            for file in train_files:
                shutil.copy(os.path.join(class_path, file), os.path.join(train_folder, file))
            for file in val_files:
                shutil.copy(os.path.join(class_path, file), os.path.join(val_folder, file))
            for file in test_files:
                shutil.copy(os.path.join(class_path, file), os.path.join(test_folder, file))

split_dataset(dataset_folder)

# New function to create a model using EfficientNetB0
def create_efficientnet_model(input_shape, num_classes):
    # Load EfficientNetB0 as the base model
    base_model = EfficientNetB0(include_top=False, weights='imagenet', input_shape=(input_shape[0], input_shape[1], 3))
    
    # Freeze the base_model
    base_model.trainable = False

    # Create a new model on top
    inputs = layers.Input(shape=input_shape)
    
    # Adapt input for EfficientNet expecting 3 channels
    x = layers.Conv2D(3, (1, 1), padding='same')(inputs)  # Adjust to keep spatial dimensions
    x = base_model(x, training=False)
    
    # Add custom top layers
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    
    model = Model(inputs, outputs)
    
    return model

# Adjusted for grayscale images
input_shape = (1024, 1024, 1)
num_classes = 3

model = create_efficientnet_model(input_shape, num_classes)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Print model summary
model.summary()

# Define directory paths
train_dir = os.path.join(dataset_folder, 'train')
validation_dir = os.path.join(dataset_folder, 'validation')
test_dir = os.path.join(dataset_folder, 'test')

# ImageDataGenerator with normalization
train_datagen = ImageDataGenerator(rescale=1./255)
validation_datagen = ImageDataGenerator(rescale=1./255)

batch_size = 32
target_size = (1024, 1024)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=target_size,
    batch_size=batch_size,
    color_mode='grayscale',  # Note: We're still loading grayscale images
    class_mode='categorical')

validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    target_size=target_size,
    batch_size=batch_size,
    color_mode='grayscale',  # Still grayscale images
    class_mode='categorical')

# Train the model
epochs = 10
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size)
# Out:
# WARNING:tensorflow:From C:\Users\Alexandra\anaconda3\envs\arenvtools\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Alexandra\anaconda3\envs\arenvtools\Lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 2s 0us/step
# WARNING:tensorflow:From C:\Users\Alexandra\anaconda3\envs\arenvtools\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 1024, 1024, 1)]   0
#
#  conv2d (Conv2D)             (None, 1024, 1024, 3)     6
#
#  efficientnetb0 (Functional  (None, 32, 32, 1280)      4049571
#  )
#
#  global_average_pooling2d (  (None, 1280)              0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 256)               327936
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 3)                 771
#
# =================================================================
# Total params: 4378284 (16.70 MB)
# Trainable params: 328713 (1.25 MB)
# Non-trainable params: 4049571 (15.45 MB)
# _________________________________________________________________
# Found 186 images belonging to 3 classes.
# Found 63 images belonging to 3 classes.
# Epoch 1/10
# WARNING:tensorflow:From C:\Users\Alexandra\anaconda3\envs\arenvtools\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Alexandra\anaconda3\envs\arenvtools\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 5/5 [==============================] - 90s 19s/step - loss: 1.1504 - accuracy: 0.2987 - val_loss: 1.1391 - val_accuracy: 0.3125
# Epoch 2/10
# 5/5 [==============================] - 64s 13s/step - loss: 1.1348 - accuracy: 0.3247 - val_loss: 1.1180 - val_accuracy: 0.4062
# Epoch 3/10
# 5/5 [==============================] - 66s 13s/step - loss: 1.1362 - accuracy: 0.3375 - val_loss: 1.1162 - val_accuracy: 0.3438
# Epoch 4/10
# 5/5 [==============================] - 64s 13s/step - loss: 1.1339 - accuracy: 0.2468 - val_loss: 1.0921 - val_accuracy: 0.3750
# Epoch 5/10
# 5/5 [==============================] - 64s 13s/step - loss: 1.1137 - accuracy: 0.3247 - val_loss: 1.0929 - val_accuracy: 0.4062
# Epoch 6/10
# 5/5 [==============================] - 63s 13s/step - loss: 1.1231 - accuracy: 0.2662 - val_loss: 1.1081 - val_accuracy: 0.2500
# Epoch 7/10
# 5/5 [==============================] - 63s 13s/step - loss: 1.0992 - accuracy: 0.3182 - val_loss: 1.0922 - val_accuracy: 0.3750
# Epoch 8/10
# 5/5 [==============================] - 63s 13s/step - loss: 1.0983 - accuracy: 0.3506 - val_loss: 1.0964 - val_accuracy: 0.3750
# Epoch 9/10
# 5/5 [==============================] - 63s 13s/step - loss: 1.1054 - accuracy: 0.3312 - val_loss: 1.1021 - val_accuracy: 0.2188
# Epoch 10/10
# 5/5 [==============================] - 64s 13s/step - loss: 1.1048 - accuracy: 0.3117 - val_loss: 1.0970 - val_accuracy: 0.4375
